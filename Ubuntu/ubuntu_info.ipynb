# %% [markdown]
# <a href="https://colab.research.google.com/github/Sra1panasa/Python/blob/main/Ubuntu/ubuntu_info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ubuntu Environment Setup:
#
# https://mkyong.com/java/how-to-add-java_home-on-ubuntu/
#
# https://askubuntu.com/questions/186693/how-set-classpath-variable-for-a-folder-in-ubuntu

# %% [markdown]
# command to know where java installed when we didn't set java_home.
#
# ![image.png](data:image/png;base64,...)
