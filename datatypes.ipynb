# %% [markdown]
# <a href="https://colab.research.google.com/github/Sra1panasa/Python/blob/main/datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Variables:**
#
# * In Python, datatypes do not have to be declare. Rather, datatypes come into existence when you assign a value to them. For example

# %%
num = 36 
print(type(num))
# Out:
# <class 'int'>

# %%
num="Python"
print(type(num))
# Out:
# <class 'str'>

# %%
num=2.7
print(type(num))
# Out:
# <class 'float'>

# %%
num=True
print(type(num))
# Out:
# <class 'bool'>

# %%
num=[1,2,3,4,5]
print(type(num))
# Out:
# <class 'list'>

# %%
print(int("abc"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-bf10fdf7813d> in <module>()
# ----> 1 print(int("abc"))
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# **Type conversion:**
#
# ![image.png](data:image/png;base64,...)
